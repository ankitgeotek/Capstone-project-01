# %%
import numpy as np

# %%
import pandas as pd

# %%
flats = pd.read_csv(r'A:\Work Docs\Data Analyst work\Campus X\10 Streamlit\Capstone\flats_cleaned.csv')
houses = pd.read_csv(r'A:\Work Docs\Data Analyst work\Campus X\10 Streamlit\Capstone\house_cleaned.csv')

# %%
flats.head(1)
# Out:
#                   property_name property_type                 society  price  \
# 0  2 BHK Flat in Krishna Colony          flat  maa bhagwati residency   0.45
#
#    price_per_sqft   area                    areaWithType  bedRoom  bathroom  \
# 0          5000.0  900.0  Carpet area: 900 (83.61 sq.m.)        2         2
#
#   balcony additionalRoom                           address  floorNum facing  \
# 0       1  not available  Krishna Colony, Gurgaon, Haryana       4.0   West
#
#      agePossession                                    nearbyLocations  \
# 0  1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
#
# ...

# %%
houses.head(1)
# Out:
#                                     property_name property_type  \
# 0  5 Bedroom House for sale in Sector 70A Gurgaon         house
#
#             society  price  price_per_sqft    area  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
#
#                   areaWithType  bedRoom  bathroom balcony additionalRoom  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+   servant room
#
#                                      address  floorNum      facing  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana       3.0  North-East
#
#      agePossession                                    nearbyLocations  \
# 0  0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
#
#                                          description  \
# 0  Do you wish to buy an independent house in sec...
#
#                                       furnishDetails  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
#
#                                             features  \
# ...

# %%
df = pd.concat([flats, houses], ignore_index=True)

# %%
df.sample(5)
# Out:
#                                        property_name property_type  \
# 374                        4 BHK Flat in DLF Phase 3          flat
# 2542                2 BHK Flat in Sector 107 Gurgaon          flat
# 3187  10 Bedroom House for sale in Sector 38 Gurgaon         house
# 3143       2 Bedroom House for sale in Vishnu Garden         house
# 353                    2 BHK Flat in Sector-33 Sohna          flat
#
#                         society  price  price_per_sqft    area  \
# 374      dlf city plots phase 3   6.50         18571.0  3500.0
# 2542  signature global solera 2   0.37          6680.0   554.0
# 3187                independent   8.00        230547.0   347.0
# 3143                independent   0.35          7778.0   450.0
# 353          godrej nature plus   1.27          9182.0  1383.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 374                    Carpet area: 3500 (325.16 sq.m.)        4         5
# ...

# %%
df.to_csv('gurgoan_property.csv', index=False)

# %%
df.shape
# Out:
# (3960, 20)
